# %%
import pandas as pd
url = 'https://ftp.ncbi.nlm.nih.gov/geo/series/GSE63nnn/GSE63885/matrix/GSE63885_series_matrix.txt.gz'
df = pd.read_csv(url, skiprows=73, sep='\t')
df.head()
# Out:
#       ID_REF  GSM1559299  GSM1559300  GSM1559301  GSM1559302  GSM1559303  \
# 0  1007_s_at   11.626937   11.821710   12.102535   11.114703   11.943312
# 1    1053_at    9.002539    8.465106    9.552282   10.080449   10.225346
# 2     117_at    7.270261    7.848213    7.889065    7.616009    7.353331
# 3     121_at   11.885396   11.778074   11.821385   11.420668   12.232684
# 4  1255_g_at    4.255623    4.602319    5.253344    4.444839    4.092267
#
#    GSM1559304  GSM1559305  GSM1559306  GSM1559307  ...  GSM1559390  \
# 0   11.983081   12.140162   12.417599   12.251480  ...   11.542659
# 1    8.870963    8.463889    9.284860    8.950363  ...    9.078212
# 2    7.974182    7.665992    7.808858    7.416200  ...    8.092317
# 3   12.057280   11.100409   12.175009   12.175954  ...   11.998523
# 4    4.554714    4.314828    4.103936    4.685622  ...    4.492559
#
#    GSM1559391  GSM1559392  GSM1559393  GSM1559394  GSM1559395  GSM1559396  \
# ...

# %%
df.shape
# Out:
# (54676, 102)

# %%
dsc = df.describe()

# %%
dsc
# Out:
#          GSM1559299    GSM1559300    GSM1559301    GSM1559302    GSM1559303  \
# count  54675.000000  54675.000000  54675.000000  54675.000000  54675.000000
# mean       7.078904      7.082793      7.096950      7.068508      7.096632
# std        2.032194      2.038204      1.973233      1.983279      2.072980
# min        3.047342      3.074364      3.105422      3.083405      3.100333
# 25%        5.619985      5.621450      5.700814      5.671218      5.578402
# 50%        6.830187      6.832520      6.935679      6.859325      6.817006
# 75%        8.422082      8.434129      8.352766      8.301783      8.507937
# max       14.237047     14.284203     14.207511     14.298569     14.277423
#
#          GSM1559304    GSM1559305    GSM1559306    GSM1559307    GSM1559308  \
# count  54675.000000  54675.000000  54675.000000  54675.000000  54675.000000
# mean       7.083822      7.084437      7.086192      7.106685      7.097287
# ...

# %%
#pas de donnees manquantes
dsc.iloc[0].plot()
# Out:
# <AxesSubplot:>

# %%
#variation d'expression 
dsc.iloc[1].plot()
# Out:
# <AxesSubplot:>

# %%
df.dropna(axis=0, inplace=True)
df.count()
# Out:
# ID_REF        54675
# GSM1559299    54675
# GSM1559300    54675
# GSM1559301    54675
# GSM1559302    54675
#               ...
# GSM1559395    54675
# GSM1559396    54675
# GSM1559397    54675
# GSM1559398    54675
# GSM1559399    54675
# Length: 102, dtype: int64

# %% [markdown]
# 2014/Lisowska
# ###
# gene expression from ovarian cancer
# ###
# clinical data : DFS and OS
# ###
# DNA chip
# ###
# 102 patients
# ###
# find a resistance biomarkers and predict pronostics
# ###
# differents type tumor / GRADE / Mutation and non-mutation (BRCA1)
# ###
# Platine / cyclophosphamide
# taxane / platine
# ###
# model prediction : Support machine vector
# ###
# testing : nearest squared
